# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel("/content/temparature.xlsx")
print(df)
min=(df['Temparature'].min())
max=(df['Temparature'].max())
avg=(df['Temparature'].mean())
print("Lowest Temparature is :",min)
print("Highest Temparature is :",max)
print("Average Temparature is :",avg)
count=0
for i in df['Temparature']:
  if(i>avg):
    count=count+1
print("Number of days the temparature exceeds the threshold temparature is :",count)
plt.title("Temparature of 50 days")
plt.plot(df['Days'],df['Temparature'],color='green')
plt.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Days  Temparature
# 0      1        29.40
# 1      2        36.50
# 2      3        25.40
# 3      4        28.10
# 4      5        29.30
# 5      6        30.10
# 6      7        22.50
# 7      8        23.50
# 8      9        23.40
# 9     10        29.50
# 10    11        26.30
# 11    12        28.40
# 12    13        35.40
# 13    14        36.80
# 14    15        23.80
# 15    16        45.80
# 16    17        41.20
# 17    18        41.30
# 18    19        35.40
# 19    20        36.20
# 20    21        31.20
# 21    22        35.20
# 22    23        32.50
# 23    24        31.40
# 24    25        30.10
# 25    26        31.40
# 26    27        32.10
# 27    28        36.40
# 28    29        32.50
# 29    30        41.30
# 30    31        44.10
# 31    32        45.20
# 32    33        46.50
# 33    34        47.50
# 34    35        45.10
# 35    36        44.50
# 36    37        44.30
# 37    38        43.10
# 38    39        42.10
# 39    40        46.50
# 40    41        42.10
# 41    42        46.10
# 42    43        45.20
# 43    44        40.20
# 44    45        41.20
# 45    46        43.20
# 46    47        42.10
# 47    48        30.20
# 48    49        31.02
# 49    50        30.20
# Lowest Temparature is : 22.5
# Highest Temparature is : 47.5
# Average Temparature is : 36.0564
# Number of days the temparature exceeds the threshold temparature is : 25
